# %%
import pandas as pd
df=pd.read_csv("ipl.csv")
df.head()
# Out:
#    mid        date                  venue  ... striker non-striker total
# 0    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 1    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 2    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 3    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 4    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
#
# [5 rows x 15 columns]

# %%
df['venue'].value_counts()
# Out:
# M Chinnaswamy Stadium                                   7443
# Feroz Shah Kotla                                        7068
# Eden Gardens                                            7049
# Wankhede Stadium                                        7048
# MA Chidambaram Stadium, Chepauk                         5972
# Rajiv Gandhi International Stadium, Uppal               5827
# Punjab Cricket Association Stadium, Mohali              4247
# Sawai Mansingh Stadium                                  4110
# Dr DY Patil Sports Academy                              2088
# Subrata Roy Sahara Stadium                              2086
# Maharashtra Cricket Association Stadium                 1843
# Kingsmead                                               1731
# Sardar Patel Stadium, Motera                            1484
# Brabourne Stadium                                       1380
# SuperSport Park                                         1377
# Punjab Cricket Association IS Bindra Stadium, Mohali    1342
# Saurashtra Cricket Association Stadium                  1229
# Himachal Pradesh Cricket Association Stadium            1115
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     1113
# New Wanderers Stadium                                    995
# St George's Park                                         870
# Dubai International Cricket Stadium                      868
# Barabati Stadium                                         856
# JSCA International Stadium Complex                       837
# Sheikh Zayed Stadium                                     836
# Sharjah Cricket Stadium                                  744
# Shaheed Veer Narayan Singh International Stadium         742
# Newlands                                                 737
# Holkar Cricket Stadium                                   617
# Nehru Stadium                                            499
# Green Park                                               492
# Buffalo Park                                             380
# Vidarbha Cricket Association Stadium, Jamtha             370
# De Beers Diamond Oval                                    368
# OUTsurance Oval                                          251
# Name: venue, dtype: int64

# %%
df['batsman'].value_counts()
# Out:
# SK Raina         1921
# V Kohli          1825
# S Dhawan         1730
# RG Sharma        1726
# MS Dhoni         1584
#                  ...
# DT Patil            1
# NJ Rimmington       1
# KP Appanna          1
# LH Ferguson         1
# YA Abdulla          1
# Name: batsman, Length: 411, dtype: int64

# %%
df.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
df['bat_team'].value_counts()
# Out:
# Mumbai Indians                 10213
# Kings XI Punjab                 9219
# Chennai Super Kings             9142
# Royal Challengers Bangalore     8331
# Kolkata Knight Riders           8033
# Delhi Daredevils                7152
# Rajasthan Royals                6643
# Deccan Chargers                 5280
# Sunrisers Hyderabad             5216
# Pune Warriors                   2448
# Gujarat Lions                   1726
# Rising Pune Supergiant           994
# Kochi Tuskers Kerala             876
# Rising Pune Supergiants          741
# Name: bat_team, dtype: int64

# %%
ActiveTeams=['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
                    'Mumbai Indians', 'Kings XI Punjab', 'Royal Challengers Bangalore',
                    'Delhi Daredevils', 'Sunrisers Hyderabad']

# %%
df=df[(df['bat_team'].isin (ActiveTeams)) & (df['bowl_team'].isin (ActiveTeams))]
df.head()
# Out:
#    mid        date                  venue  ... striker non-striker total
# 0    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 1    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 2    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 3    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
# 4    1  2008-04-18  M Chinnaswamy Stadium  ...       0           0   222
#
# [5 rows x 15 columns]

# %%
df['bat_team'].value_counts()
# Out:
# Mumbai Indians                 8461
# Kings XI Punjab                7889
# Chennai Super Kings            7536
# Royal Challengers Bangalore    6843
# Kolkata Knight Riders          6300
# Rajasthan Royals               6038
# Delhi Daredevils               6022
# Sunrisers Hyderabad            4722
# Name: bat_team, dtype: int64

# %%
df=pd.get_dummies(df,columns=['bat_team','bowl_team'])
df.head()
# Out:
#    mid  ... bowl_team_Sunrisers Hyderabad
# 0    1  ...                             0
# 1    1  ...                             0
# 2    1  ...                             0
# 3    1  ...                             0
# 4    1  ...                             0
#
# [5 rows x 29 columns]

# %%
df.drop(['striker','non-striker','mid'],axis=1,inplace=True)

# %%
df=df[df['overs']>5.0]

# %%
df.head()
# Out:
#           date  ... bowl_team_Sunrisers Hyderabad
# 32  2008-04-18  ...                             0
# 33  2008-04-18  ...                             0
# 34  2008-04-18  ...                             0
# 35  2008-04-18  ...                             0
# 36  2008-04-18  ...                             0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['date', 'venue', 'batsman', 'bowler', 'runs', 'wickets', 'overs',
#        'runs_last_5', 'wickets_last_5', 'total',
#        'bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils',
#        'bat_team_Kings XI Punjab', 'bat_team_Kolkata Knight Riders',
#        'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
#        'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
#        'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils',
#        'bowl_team_Kings XI Punjab', 'bowl_team_Kolkata Knight Riders',
#        'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
#        'bowl_team_Royal Challengers Bangalore',
#        'bowl_team_Sunrisers Hyderabad'],
#       dtype='object')

# %%
final_df=df[['date','bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
              'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
              'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
              'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils', 'bowl_team_Kings XI Punjab',
              'bowl_team_Kolkata Knight Riders', 'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
              'bowl_team_Royal Challengers Bangalore', 'bowl_team_Sunrisers Hyderabad',
              'overs', 'runs', 'wickets', 'runs_last_5', 'wickets_last_5', 'total']]

final_df.head()
# Out:
#           date  bat_team_Chennai Super Kings  ...  wickets_last_5  total
# 32  2008-04-18                             0  ...               0    222
# 33  2008-04-18                             0  ...               1    222
# 34  2008-04-18                             0  ...               1    222
# 35  2008-04-18                             0  ...               1    222
# 36  2008-04-18                             0  ...               1    222
#
# [5 rows x 23 columns]

# %%
from datetime import datetime
final_df['date']=final_df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df=pd.get_dummies(df,columns=['venue'], drop_first=True)
df.head()
# Out:
#           date      batsman  ... venue_SuperSport Park  venue_Wankhede Stadium
# 32  2008-04-18  BB McCullum  ...                     0                       0
# 33  2008-04-18   SC Ganguly  ...                     0                       0
# 34  2008-04-18   RT Ponting  ...                     0                       0
# 35  2008-04-18   RT Ponting  ...                     0                       0
# 36  2008-04-18   RT Ponting  ...                     0                       0
#
# [5 rows x 55 columns]

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopwords=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['comb'] = df['batsman'] + ' ' + df['bowler']
df.drop(columns=['batsman','bowler'],axis=1, inplace=True)
df['comb'] = df['comb'].str.lower()
df.head()
# Out:
#           date  runs  ...  venue_Wankhede Stadium                comb
# 32  2008-04-18    61  ...                       0  bb mccullum z khan
# 33  2008-04-18    61  ...                       0   sc ganguly z khan
# 34  2008-04-18    61  ...                       0   rt ponting z khan
# 35  2008-04-18    61  ...                       0   rt ponting z khan
# 36  2008-04-18    61  ...                       0   rt ponting z khan
#
# [5 rows x 54 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
from tqdm.auto import tqdm
import numpy as np

comb = list(df['comb'])
tfidf = TfidfVectorizer(lowercase=False, )
X=tfidf.fit_transform(comb)
print(X.shape)
# dict key:word and value:tf-idf score
word2tfidf = dict(zip(tfidf.get_feature_names(), tfidf.idf_))
print(word2tfidf)
nlp = spacy.load('en_core_web_sm')

vecs1 = []

for i in tqdm(list(df['comb'])):
    combdata = nlp(i) 
    # 384 is the number of dimensions of vectors 
    mean_vec1 = np.zeros([len(comb), len(combdata[0].vector)])
    for word1 in combdata:
        # word2vec
        vec1 = word1.vector
        # fetch df score
        try:
            idf = word2tfidf[str(word1)]
        except:
            idf = 0
        # compute final vec
        mean_vec1 += vec1 * idf
    mean_vec1 = mean_vec1.mean(axis=0)
    vecs1.append(mean_vec1)
df['comb_feats_m'] = list(vecs1)
# Out:
# (40088, 550)
# {'aa': 6.232881246427319, 'aaron': 5.602405172830149, 'ab': 4.227367966234894, 'abbott': 8.507814808090854, 'abdulla': 5.766974784165654, 'abdur': 8.890807060346962, 'ablish': 8.07249673683301, 'ac': 6.085428515284188, 'ad': 4.805391128869161, 'af': 10.905710080889225, 'ag': 7.837657145755609, 'agarkar': 5.846284622623537, 'agarwal': 6.693582483010741, 'ahmed': 6.778575695844133, 'aj': 6.480863449032415, 'akhil': 6.964128273219535, 'akhtar': 9.40163268411295, 'akmal': 8.231561431462698, 'al': 5.042078905291128, 'am': 4.940846215578422, 'amarnath': 7.987939348804946, 'amla': 6.87146944273683, 'an': 6.778575695844133, 'anand': 7.909977807335235, 'anderson': 5.939375045689549, 'anirudha': 7.628565347897049, 'ankit': 7.034509069981334, 'anureet': 6.555432144529924, 'ap': 7.144509965195663, 'appanna': 7.294792168245001, 'ar': 5.062165663857866, 'aravind': 6.523683446215344, 'arun': 8.266652751273966, 'as': 6.555432144529924, 'ashish': 6.731322810993588, 'ashwin': 4.990856636153083, 'asif': 7.792194771678851, 'asnodkar': 6.916726034324951, 'at': 5.004443801699392, 'auk': 9.519415719769334, 'awana': 6.069428173937747, 'azhar': 5.872009513861974, 'ba': 7.538414250902751, 'baby': 7.439974178089499, 'badree': 7.591524076216699, 'badrinath': 5.4418782758636155, 'bailey': 6.13079712031404, 'balaji': 5.512082534536864, 'baw': 7.132949142794587, 'bawne': 9.033907903987634, 'bb': 5.307288121890851, 'bcj': 7.3793495562730635, 'be': 8.01533832299306, 'bhatia': 4.882262487928193, 'bhatkal': 10.500244972781061, 'bhatt': 7.538414250902751, 'billings': 7.409202519422745, 'binny': 5.469807051388625, 'bipul': 6.6360126311892635, 'bisla': 7.07706868440013, 'bj': 5.580264046952936, 'blizzard': 9.807097792221116, 'bmaj': 8.507814808090854, 'bollinger': 6.935418167337104, 'bond': 7.573505570714022, 'bopara': 5.9820861637826, 'botha': 6.0773963435869245, 'boucher': 6.907509379220027, 'boult': 7.538414250902751, 'bracewell': 8.603124987895178, 'brathwaite': 6.944896911291647, 'bravo': 4.579560607734126, 'bumrah': 5.688060617408643, 'butt': 7.935295615319524, 'buttler': 7.792194771678851, 'bw': 7.204408106776732, 'ca': 6.954466362307798, 'cariappa': 6.862658813054675, 'carseldine': 8.37998143658097, 'ch': 4.487345144953014, 'chahal': 5.42091314739857, 'chand': 7.003737411314581, 'chandila': 7.837657145755609, 'chavan': 7.961271101722785, 'chawla': 4.449725662891764, 'chitnis': 7.364750756851911, 'chopra': 10.500244972781061, 'choudhary': 8.07249673683301, 'christian': 8.765643917392953, 'cj': 5.6826551988417355, 'ck': 7.168040462605857, 'cl': 6.568419340056735, 'cm': 7.935295615319524, 'collingwood': 6.693582483010741, 'cooper': 5.862284963969978, 'coulter': 6.266138468183802, 'cr': 6.139271747305012, 'crd': 7.055562479179167, 'cummins': 6.49291178754859, 'cutting': 7.3793495562730635, 'da': 4.5230483974707845, 'daj': 8.603124987895178, 'das': 7.066257768295914, 'db': 7.066257768295914, 'de': 4.526435360911799, 'der': 5.964067658279921, 'dh': 7.024146282945788, 'dhawan': 4.888334151996743, 'dhoni': 4.614140941330906, 'dilshan': 5.764046524386566, 'dinda': 6.143536146091469, 'dj': 3.9766826666315485, 'djg': 6.045897676527553, 'dl': 5.827416138319155, 'doeschate': 6.594910955503711, 'dogra': 7.192138014184917, 'dole': 8.340760723427689, 'dp': 6.594910955503711, 'dpmd': 6.034336854126477, 'dr': 5.487389921946492, 'dravid': 5.341189673566532, 'ds': 5.824305715904762, 'dt': 8.708485503553007, 'du': 6.118218338107179, 'duminy': 4.909257992270204, 'dw': 5.640432568419389, 'ejg': 6.034336854126477, 'faulkner': 5.354690360785434, 'fazal': 7.2681239211628395, 'fernando': 7.055562479179167, 'finch': 6.480863449032415, 'fleming': 8.82626853920939, 'flintoff': 7.55580599361462, 'franklin': 6.803066715852429, 'fy': 7.2681239211628395, 'gagandeep': 8.65441828228273, 'gambhir': 5.327868829590871, 'ganapathy': 9.652947112393857, 'ganguly': 5.949883023287964, 'gautam': 7.935295615319524, 'gavaskar': 9.652947112393857, 'gayle': 4.935724565458368, 'gb': 6.315653532711182, 'gc ...
# HBox(children=(FloatProgress(value=0.0, max=40088.0), HTML(value='')))

# %%
df.head()
# Out:
#           date  ...                                       comb_feats_m
# 32  2008-04-18  ...  [29.05875015258789, -12.874543190002441, 1.619...
# 33  2008-04-18  ...  [8.409851551055908, -30.29967212677002, -6.675...
# 34  2008-04-18  ...  [25.488882780075073, -25.937082529067993, -20....
# 35  2008-04-18  ...  [25.488882780075073, -25.937082529067993, -20....
# 36  2008-04-18  ...  [25.488882780075073, -25.937082529067993, -20....
#
# [5 rows x 55 columns]

# %%
df1=df.drop(['comb'],axis=1)
df2=pd.DataFrame(df1.comb_feats_m.tolist(),index=df1.index)

# %%
df2.head()
# Out:
#            0          1          2   ...         93         94         95
# 32  29.058750 -12.874543   1.619512  ...  44.099900 -17.541222   0.485047
# 33   8.409852 -30.299672  -6.675205  ...  55.526933 -19.298930  11.304518
# 34  25.488883 -25.937083 -20.960962  ...  56.900839 -13.749451 -25.975318
# 35  25.488883 -25.937083 -20.960962  ...  56.900839 -13.749451 -25.975318
# 36  25.488883 -25.937083 -20.960962  ...  56.900839 -13.749451 -25.975318
#
# [5 rows x 96 columns]

# %%
df3=pd.concat([df1,df2],axis=1)
df3.drop(['comb_feats_m'],axis=1)
df3.head()
df3.shape
# Out:
# (40088, 150)

# %%
df3.columns
# Out:
# Index([                        'date',                         'runs',
#                             'wickets',                        'overs',
#                         'runs_last_5',               'wickets_last_5',
#                               'total', 'bat_team_Chennai Super Kings',
#           'bat_team_Delhi Daredevils',     'bat_team_Kings XI Punjab',
#        ...
#                                    86,                             87,
#                                    88,                             89,
#                                    90,                             91,
#                                    92,                             93,
#                                    94,                             95],
#       dtype='object', length=150)

# %%
X_train = final_df.drop(labels='total', axis=1)[final_df['date'].dt.year <= 2016]
X_test = final_df.drop(labels='total', axis=1)[final_df['date'].dt.year >= 2017]

y_train = final_df[final_df['date'].dt.year <= 2016]['total'].values
y_test = final_df[final_df['date'].dt.year >= 2017]['total'].values

X_train.drop(labels='date', axis=True, inplace=True)
X_test.drop(labels='date', axis=True, inplace=True)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predreg=regressor.predict(X_test)

# %%
from sklearn import metrics
import numpy as np
print('MAE:', metrics.mean_absolute_error(y_test, y_predreg))
print('MSE:', metrics.mean_squared_error(y_test, y_predreg))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predreg)))
# Out:
# MAE: 12.118024556233127
# MSE: 251.01241656930586
# RMSE: 15.843371376361342

# %%
from sklearn import svm

regr=svm.SVR(kernel='rbf')
regr.fit(X_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred=regr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 14.475294914805614
# MSE: 361.32278747000584
# RMSE: 19.008492509139327

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X_train,y_train)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4553399.734970139, tolerance: 2528.7619405923406
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4354388.402507149, tolerance: 2545.6442729529654
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4404296.04191213, tolerance: 2666.746567247386
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4272401.182360366, tolerance: 2710.741184132963
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4533974.60681972, tolerance: 2645.683196083479
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 588753.4829277731, tolerance: 2528.7619405923406
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 482590.0967411073, tolerance: 2545.6442729529654
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253563.07920884527, tolerance: 2666.746567247386
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 273191.9763838062, tolerance: 2710.741184132963
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 328198.5721764248, tolerance: 2645.683196083479
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 588751.3752616467, tolerance: 2528.7619405923406
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 482588.870148059, tolerance: 2545.6442729529654
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253562.68543758243, tolerance: 2666.746567247386
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 273194.39550096635, tolerance: 2710.741184132963
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 328198.5356845502, tolerance: 2645.683196083479
#   positive)
# {'alpha': 1}
# -320.7289357212224

# %%
pred_lasso=lasso_regressor.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:', metrics.mean_squared_error(y_test, pred_lasso))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# MAE: 12.213767557786616
# MSE: 262.3732928663518
# RMSE: 16.197941007003074

# %%
import pickle
filename = 'IPLScorePrediction.pkl'
pickle.dump(lasso_regressor, open(filename, 'wb'))

# %%
IPLScorePredictionPickle=pickle.load(open('IPLScorePrediction.pkl','rb'))
predictions_score=IPLScorePredictionPickle.predict(X_test)
metrics.r2_score(y_test, pred_lasso)
# Out:
# 0.741046106913757

# %%
df_match=pd.read_csv('matches.csv')
df_match.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
df_win=df_match['team1']+ df_match['team2']
df_win.head()
# Out:
# 0    Sunrisers HyderabadRoyal Challengers Bangalore
# 1              Mumbai IndiansRising Pune Supergiant
# 2                Gujarat LionsKolkata Knight Riders
# 3             Rising Pune SupergiantKings XI Punjab
# 4       Royal Challengers BangaloreDelhi Daredevils
# dtype: object

# %%
subsetDataFrame = df_match[df_match['team1'] == df_match['winner']]
subsetDataFrame['winner']=1
subsetDataFrame.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     id    Season       city  ...      umpire1      umpire2 umpire3
# 0    1  IPL-2017  Hyderabad  ...  AY Dandekar     NJ Llong     NaN
# 4    5  IPL-2017  Bangalore  ...          NaN          NaN     NaN
# 8    9  IPL-2017       Pune  ...  AY Dandekar       S Ravi     NaN
# 13  14  IPL-2017    Kolkata  ...  AY Dandekar     NJ Llong     NaN
# 14  15  IPL-2017      Delhi  ...     YC Barde  Nitin Menon     NaN
#
# [5 rows x 18 columns]

# %%
subsetDataFrame2 = df_match[df_match['team2'] == df_match['winner']]
subsetDataFrame2['winner']=0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
subsetDataFrame2.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 5   6  IPL-2017  Hyderabad  ...      A Deshmukh       NJ Llong     NaN
# 6   7  IPL-2017     Mumbai  ...     Nitin Menon      CK Nandan     NaN
#
# [5 rows x 18 columns]

# %%
df_concat = pd.concat([subsetDataFrame, subsetDataFrame2], axis=0)
df_concat.head()
# Out:
#     id    Season       city  ...      umpire1      umpire2 umpire3
# 0    1  IPL-2017  Hyderabad  ...  AY Dandekar     NJ Llong     NaN
# 4    5  IPL-2017  Bangalore  ...          NaN          NaN     NaN
# 8    9  IPL-2017       Pune  ...  AY Dandekar       S Ravi     NaN
# 13  14  IPL-2017    Kolkata  ...  AY Dandekar     NJ Llong     NaN
# 14  15  IPL-2017      Delhi  ...     YC Barde  Nitin Menon     NaN
#
# [5 rows x 18 columns]

# %%
df_concat.tail()
# Out:
#         id    Season  ...         umpire2                  umpire3
# 750  11346  IPL-2019  ...   C Shamshuddin           Bruce Oxenford
# 751  11347  IPL-2019  ...        O Nandan                   S Ravi
# 752  11412  IPL-2019  ...     Nitin Menon                Ian Gould
# 753  11413  IPL-2019  ...             NaN                      NaN
# 754  11414  IPL-2019  ...  Bruce Oxenford  Chettithody Shamshuddin
#
# [5 rows x 18 columns]

# %%
df_winner=df_concat['winner']
df_winner.head()
df_team2=df_match['team2']
df_team1=df_match['team1']

# %%
df_win=pd.concat([df_team1,df_team2,df_winner], axis=1)
df_win.head()
# Out:
#                          team1                        team2  winner
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore     1.0
# 1               Mumbai Indians       Rising Pune Supergiant     0.0
# 2                Gujarat Lions        Kolkata Knight Riders     0.0
# 3       Rising Pune Supergiant              Kings XI Punjab     0.0
# 4  Royal Challengers Bangalore             Delhi Daredevils     1.0

# %%
ActiveTeams=['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
                    'Mumbai Indians', 'Kings XI Punjab', 'Royal Challengers Bangalore',
                    'Delhi Daredevils', 'Sunrisers Hyderabad']

# %%
df_win=df_win[(df_win['team1'].isin (ActiveTeams)) & (df_win['team2'].isin (ActiveTeams))]
df_win.head()
# Out:
#                          team1                        team2  winner
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore     1.0
# 4  Royal Challengers Bangalore             Delhi Daredevils     1.0
# 6        Kolkata Knight Riders               Mumbai Indians     0.0
# 7  Royal Challengers Bangalore              Kings XI Punjab     0.0
# 9          Sunrisers Hyderabad               Mumbai Indians     0.0

# %%
df_win=pd.get_dummies(df_win,columns=['team1','team2'])

# %%
df_win.head()
# Out:
#    winner  ...  team2_Sunrisers Hyderabad
# 0     1.0  ...                          0
# 4     1.0  ...                          0
# 6     0.0  ...                          0
# 7     0.0  ...                          0
# 9     0.0  ...                          0
#
# [5 rows x 17 columns]

# %%
df_win.columns
# Out:
# Index(['winner', 'team1_Chennai Super Kings', 'team1_Delhi Daredevils',
#        'team1_Kings XI Punjab', 'team1_Kolkata Knight Riders',
#        'team1_Mumbai Indians', 'team1_Rajasthan Royals',
#        'team1_Royal Challengers Bangalore', 'team1_Sunrisers Hyderabad',
#        'team2_Chennai Super Kings', 'team2_Delhi Daredevils',
#        'team2_Kings XI Punjab', 'team2_Kolkata Knight Riders',
#        'team2_Mumbai Indians', 'team2_Rajasthan Royals',
#        'team2_Royal Challengers Bangalore', 'team2_Sunrisers Hyderabad'],
#       dtype='object')

# %%
final_df_win=df_win[['team1_Chennai Super Kings', 'team1_Delhi Daredevils',
       'team1_Kings XI Punjab', 'team1_Kolkata Knight Riders',
       'team1_Mumbai Indians', 'team1_Rajasthan Royals',
       'team1_Royal Challengers Bangalore', 'team1_Sunrisers Hyderabad',
       'team2_Chennai Super Kings', 'team2_Delhi Daredevils',
       'team2_Kings XI Punjab', 'team2_Kolkata Knight Riders',
       'team2_Mumbai Indians', 'team2_Rajasthan Royals',
       'team2_Royal Challengers Bangalore', 'team2_Sunrisers Hyderabad', 'winner']]
final_df_win.head()
# Out:
#    team1_Chennai Super Kings  ...  winner
# 0                          0  ...     1.0
# 4                          0  ...     1.0
# 6                          0  ...     0.0
# 7                          0  ...     0.0
# 9                          0  ...     0.0
#
# [5 rows x 17 columns]

# %%
final_df_win.isnull().sum()
# Out:
# team1_Chennai Super Kings            0
# team1_Delhi Daredevils               0
# team1_Kings XI Punjab                0
# team1_Kolkata Knight Riders          0
# team1_Mumbai Indians                 0
# team1_Rajasthan Royals               0
# team1_Royal Challengers Bangalore    0
# team1_Sunrisers Hyderabad            0
# team2_Chennai Super Kings            0
# team2_Delhi Daredevils               0
# team2_Kings XI Punjab                0
# team2_Kolkata Knight Riders          0
# team2_Mumbai Indians                 0
# team2_Rajasthan Royals               0
# team2_Royal Challengers Bangalore    0
# team2_Sunrisers Hyderabad            0
# winner                               3
# dtype: int64

# %%
final_df_win.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df_win.isnull().sum()
# Out:
# team1_Chennai Super Kings            0
# team1_Delhi Daredevils               0
# team1_Kings XI Punjab                0
# team1_Kolkata Knight Riders          0
# team1_Mumbai Indians                 0
# team1_Rajasthan Royals               0
# team1_Royal Challengers Bangalore    0
# team1_Sunrisers Hyderabad            0
# team2_Chennai Super Kings            0
# team2_Delhi Daredevils               0
# team2_Kings XI Punjab                0
# team2_Kolkata Knight Riders          0
# team2_Mumbai Indians                 0
# team2_Rajasthan Royals               0
# team2_Royal Challengers Bangalore    0
# team2_Sunrisers Hyderabad            0
# winner                               0
# dtype: int64

# %%
X=final_df_win.iloc[:,:-1]
y=final_df_win.iloc[:,-1]
X.head()
# Out:
#    team1_Chennai Super Kings  ...  team2_Sunrisers Hyderabad
# 0                          0  ...                          0
# 4                          0  ...                          0
# 6                          0  ...                          0
# 7                          0  ...                          0
# 9                          0  ...                          0
#
# [5 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

tuned_param=[{'C':[10^-4,10^-2,10^0,10^2,10^4]}]
model=GridSearchCV(LogisticRegression(),tuned_param,scoring='f1',cv=5)

model.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Penalty term must be positive; got (C=-10)
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Penalty term must be positive; got (C=-12)
#
#   FitFailedWarning)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'C': [-10, -12, 10, 8, 14]}], pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring='f1', verbose=0)

# %%
print(model.best_estimator_)
print(model.best_params_)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# {'C': 10}

# %%
y_prediction=model.predict(test_x)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(test_y, y_prediction))
print('MSE:', metrics.mean_squared_error(test_y, y_prediction))
# Out:
# MAE: 0.3674698795180723
# MSE: 0.3674698795180723

# %%
import pickle

pickle.dump(Logreg,open('WinnerPrediction.pkl','wb'))

# %%
WinnerPredictionPickle=pickle.load(open('WinnerPrediction.pkl','rb'))
predictions=WinnerPredictionPickle.predict(test_x)
metrics.r2_score(test_y, predictions)
# Out:
# -0.4561403508771926
